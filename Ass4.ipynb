# %%
import pandas as pd

# %%
# importing the dataset
netflix = pd.read_csv(r'C:\Users\daved\Downloads\Download\netflix_titles.csv')

# %%
# Checking the dataset by viewing the top 5 rows
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# Checking numbers of rows and columns
netflix.shape
# Out:
# (8807, 12)

# %%
# checking for the names of columns in the dataset
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# checking for the data types of the columns in the dataset
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# checking for null values in the dataset
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### Data Cleaning

# %%
# Cleaning our country columns with null by given it value 'unknown' 
netflix['country'] = netflix['country'].fillna('unknown')

# %%
# checking if it worked
netflix[['country']].head(10)
# Out:
#                                              country
# 0                                      United States
# 1                                       South Africa
# 2                                            unknown
# 3                                            unknown
# 4                                              India
# 5                                            unknown
# 6                                            unknown
# 7  United States, Ghana, Burkina Faso, United Kin...
# 8                                     United Kingdom
# 9                                      United States

# %%
# dropping rows with null values in title and type colums
netflix = netflix.dropna(subset=['title', 'type'])

# %%
# checking if null values still exist in title and type columns
netflix[['title', 'type']].isnull().sum()
# Out:
# title    0
# type     0
# dtype: int64

# %% [markdown]
# #### Flitering, Aggregating, and Performing Conditioninal functions on the dataset

# %%
# checking how many are Movies and Tv shows in the type column
netflix['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# checking for top 10 most frequent countries
netflix['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
# converting date_added column to datetime format
netflix['date_added'] = pd.to_datetime(netflix['date_added'], errors= 'coerce')

# %%
# checking the data type of date_added columns
# it checked to datetime
netflix.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
# creating new column year_added from date_added
netflix['year_added'] = netflix['date_added'].dt.year

# %%
# checking the year_added column
netflix[['title', 'date_added', 'year_added']].head(10)
# Out:
#                               title date_added  year_added
# 0              Dick Johnson Is Dead        NaT         NaN
# 1                     Blood & Water        NaT         NaN
# 2                         Ganglands        NaT         NaN
# 3             Jailbirds New Orleans        NaT         NaN
# 4                      Kota Factory        NaT         NaN
# 5                     Midnight Mass        NaT         NaN
# 6  My Little Pony: A New Generation        NaT         NaN
# 7                           Sankofa        NaT         NaN
# 8     The Great British Baking Show        NaT         NaN
# 9                      The Starling        NaT         NaN

# %%
# checking all shows released before the year 2000
netflix[netflix['release_year'] < 2000]
# Out:
#      show_id   type                                title          director  \
# 7         s8  Movie                              Sankofa      Haile Gerima
# 22       s23  Movie                      Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie                                Jeans        S. Shankar
# 26       s27  Movie                       Minsara Kanavu       Rajiv Menon
# 41       s42  Movie                                 Jaws  Steven Spielberg
# ...      ...    ...                                  ...               ...
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory        Mel Stuart
# 8748   s8749  Movie                 Winter of Our Dreams       John Duigan
# 8763   s8764  Movie      WWII: Report from the Aleutians       John Huston
# 8764   s8765  Movie                           Wyatt Earp   Lawrence Kasdan
# 8792   s8793  Movie                          Young Tiger            Mu Chu
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 26    Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P....
# 41    Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ...                                                 ...
# 8745  Gene Wilder, Jack Albertson, Peter Ostrum, Roy...
# 8748  Judy Davis, Bryan Brown, Cathy Downes, Baz Luh...
# 8763                                                NaN
# 8764  Kevin Costner, Dennis Quaid, Gene Hackman, Dav...
# 8792  Qiu Yuen, Charlie Chin, Jackie Chan, Hu Chin, ...
#
#                                                 country date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin...        NaT
# 22                                              unknown        NaT
# 24                                                India        NaT
# 26                                              unknown        NaT
# 41                                        United States        NaT
# ...                                                 ...        ...
# 8745          United States, East Germany, West Germany        NaT
# 8748                                          Australia        NaT
# 8763                                      United States        NaT
# 8764                                      United States        NaT
# 8792                                          Hong Kong        NaT
#
#       release_year rating duration  \
# 7             1993  TV-MA  125 min
# 22            1996  TV-PG  161 min
# 24            1998  TV-14  166 min
# 26            1997  TV-PG  147 min
# 41            1975     PG  124 min
# ...            ...    ...      ...
# 8745          1971      G  100 min
# 8748          1981     NR   86 min
# 8763          1943  TV-PG   45 min
# 8764          1994  PG-13  191 min
# 8792          1973     NR   81 min
#
#                                               listed_in  \
# 7      Dramas, Independent Movies, International Movies
# 22                       Comedies, International Movies
# 24      Comedies, International Movies, Romantic Movies
# 26     Comedies, International Movies, Music & Musicals
# 41           Action & Adventure, Classic Movies, Dramas
# ...                                                 ...
# 8745  Children & Family Movies, Classic Movies, Come...
# 8748                             Classic Movies, Dramas
# 8763                                      Documentaries
# 8764                                 Action & Adventure
# 8792           Action & Adventure, International Movies
#
#                                             description  year_added
# 7     On a photo shoot in Ghana, an American model s...         NaN
# 22    Newly divorced and denied visitation rights wi...         NaN
# 24    When the father of the man she loves insists t...         NaN
# 26    A tangled love triangle ensues when a man fall...         NaN
# 41    When an insatiable great white shark terrorize...         NaN
# ...                                                 ...         ...
# 8745  Zany Willy Wonka causes a stir when he announc...         NaN
# 8748  After the death of a long-ago lover, married p...         NaN
# 8763  Filmmaker John Huston narrates this Oscar-nomi...         NaN
# 8764  Legendary lawman Wyatt Earp is continually at ...         NaN
# 8792  Aided only by a tough female police officer, a...         NaN
#
# [525 rows x 13 columns]

# %%
# checking most common genre in listed_in column

from collections import Counter

# split by comma and flatten the list
genres = netflix['listed_in'].dropna().str.split(',')
genre_counts = Counter([genre for sublist in genres for genre in sublist])
genre_counts.most_common(1)
# Out:
# [(' International Movies', 2624)]

# %%
# showing show directed by 'Rajikumar Hirani'
netflix[netflix['director'] == 'Rajikumar Hirani']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year_added]
# Index: []

# %%
# counting how many shows fall under each rating
netflix['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# filtering movies with duration more than 100 minutes

# Only apply to movies
movies = netflix[netflix['type'] == 'Movie'].copy()

# extracting duration as number
movies['content_length'] = movies['duration'].str.extract(r'(\d+)').astype(float)

# filter
movies_over_100 = movies[movies['content_length'] > 100]
movies_over_100[['title', 'duration', 'content_length']].head()
# Out:
#               title duration  content_length
# 7           Sankofa  125 min           125.0
# 9      The Starling  104 min           104.0
# 12     Je Suis Karl  127 min           127.0
# 22  Avvai Shanmughi  161 min           161.0
# 24            Jeans  166 min           166.0

# %%
# creating 'content_length' column from duration
netflix['content_length'] = netflix['duration'].str.extract(r'(\d+)').astype(float)

# %%
# checking content_length from duration column
netflix[['title', 'duration', 'content_length']].head(10)
# Out:
#                               title   duration  content_length
# 0              Dick Johnson Is Dead     90 min            90.0
# 1                     Blood & Water  2 Seasons             2.0
# 2                         Ganglands   1 Season             1.0
# 3             Jailbirds New Orleans   1 Season             1.0
# 4                      Kota Factory  2 Seasons             2.0
# 5                     Midnight Mass   1 Season             1.0
# 6  My Little Pony: A New Generation     91 min            91.0
# 7                           Sankofa    125 min           125.0
# 8     The Great British Baking Show  9 Seasons             9.0
# 9                      The Starling    104 min           104.0

# %%
# sorting the dataset by release_year in descending order

netflix_sorted = netflix.sort_values(by = 'release_year', ascending = False)

# %%
# checking the dataset sorted
netflix_sorted[['title', 'release_year']].head(10)
# Out:
#                                      title  release_year
# 693                 Ali & Ratu Ratu Queens          2021
# 781  Black Holes | The Edge of All We Know          2021
# 762                           Sweet & Sour          2021
# 763                            Sweet Tooth          2021
# 764           Trippin' with the Kandasamys          2021
# 765                                 Xtreme          2021
# 766                Alan Saldaña: Locked Up          2021
# 767                   Creator's File: GOLD          2021
# 768                         Dancing Queens          2021
# 770              Myriam Fares: The Journey          2021

# %% [markdown]
# Exporting the Cleaned Dataset

# %%
netflix.to_csv('netflix_cleaned.csv', index = False)
